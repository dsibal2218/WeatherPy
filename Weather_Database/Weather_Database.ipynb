# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a6da1a845cc9d4e72a72f7147a3a339

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['tiksi',
#  'punta arenas',
#  'busselton',
#  'lorengau',
#  'lebu',
#  'geraldton',
#  'manaus',
#  'vaini',
#  'butaritari',
#  'cervo',
#  'saint-philippe',
#  'atuona',
#  'severo-kurilsk',
#  'kloulklubed',
#  'pevek',
#  'labuhan',
#  'airai',
#  'mahebourg',
#  'chicama',
#  'port elizabeth',
#  'ushuaia',
#  'albany',
#  'kapoeta',
#  'fortuna',
#  'kirakira',
#  'sembe',
#  'tazovskiy',
#  'qandahar',
#  'port alfred',
#  'yulara',
#  'port hawkesbury',
#  'belushya guba',
#  'kitui',
#  'new norfolk',
#  'upernavik',
#  'dikson',
#  'makakilo city',
#  'arraial do cabo',
#  'traverse city',
#  'mitu',
#  'saleaula',
#  'tasiilaq',
#  'oistins',
#  'attawapiskat',
#  'rikitea',
#  'qaanaaq',
#  'fairbanks',
#  'sitka',
#  'zvishavane',
#  'kruisfontein',
#  'mareeba',
#  'pochutla',
#  'galesong',
#  'vostok',
#  'carnarvon',
#  'pangnirtung',
#  'sam chuk',
#  'hermanus',
#  'batyrevo',
#  'vestmannaeyjar',
#  'barcelos',
#  'constitucion',
#  'tuktoyaktuk',
#  'georgetown',
#  'klaksvik',
#  'yellowknife',
#  'saskylakh',
#  'lovington',
#  'mayo',
#  'margate',
#  'porto velho',
#  'villazon',
#  'alofi',
#  'taolanaro',
#  'sierra vista',
#  'sehithwa',
#  'san patricio',
#  'mataura',
#  'cape town',
#  'castro',
#  'hobart',
#  'salinopolis',
#  'hunza',
#  'jiuquan',
#  'sirari',
#  'rawson',
#  'mar del plata',
#  'kodiak',
#  'richards bay',
#  'winthrop',
#  'half moon bay',
#  'astana',
#  'oriximina',
#  'tual',
#  'ribeira grande',
#  'fallon',
#  'dasoguz',
#  'saldanha',
#  'sentyabrskiy',
#  'hasaki',
#  'rock springs',
#  'ixtapa',
#  'faya',
#  'hay river',
#  'torbay',
#  'chake chake',
#  'kodinar',
#  'mehamn',
#  'teguldet',
#  'vila velha',
#  'mys shmidta',
#  'padang',
#  'eureka',
#  'bluff',
#  'kabanjahe',
#  'amderma',
#  'bamnet narong',
#  'waipawa',
#  'tura',
#  'provideniya',
#  'bredasdorp',
#  'maceio',
#  'yaan',
#  'christchurch',
#  'leningradskiy',
#  'mazyr',
#  'pelym',
#  'hovd',
#  'illoqqortoormiut',
#  'grimari',
#  'kaitangata',
#  'qandala',
#  'ranfurly',
#  'nikolskoye',
#  'priladozhskiy',
#  'ponta do sol',
#  'yumen',
#  'chuy',
#  'pacific grove',
#  'grand river south east',
#  'beloha',
#  'marsa matruh',
#  'bairiki',
#  'ust-maya',
#  'kapaa',
#  'bengkulu',
#  'kerema',
#  'east london',
#  'puerto colombia',
#  'tumannyy',
#  'olafsvik',
#  'tias',
#  'ilulissat',
#  'avarua',
#  'ahumada',
#  'thompson',
#  'sao filipe',
#  'hamilton',
#  'udachnyy',
#  'novyy urengoy',
#  'almaznyy',
#  'norman wells',
#  'novikovo',
#  'hue',
#  'kemin',
#  'tilichiki',
#  'flin flon',
#  'oppdal',
#  'luangwa',
#  'cardston',
#  'barrow',
#  'hilo',
#  'gat',
#  'progreso',
#  'arcata',
#  'aksay',
#  'santa maria',
#  'codrington',
#  'kamina',
#  'imeni poliny osipenko',
#  'puerto ayora',
#  'boundiali',
#  'bauchi',
#  'khandyga',
#  'patitirion',
#  'saint-leu',
#  'leiyang',
#  'port hardy',
#  'jamestown',
#  'bambous virieux',
#  'nanortalik',
#  'khandbari',
#  'cabo san lucas',
#  'marzuq',
#  'rafiganj',
#  'champerico',
#  'esperance',
#  'zhangye',
#  'calvia',
#  'talnakh',
#  'victoria',
#  'pisco',
#  'guerrero negro',
#  'blackwater',
#  'cegrane',
#  'bangassou',
#  'saint anthony',
#  'waingapu',
#  'barawe',
#  'uberaba',
#  'asau',
#  'tirodi',
#  'jieshi',
#  'pawayan',
#  'hithadhoo',
#  'carballo',
#  'arkhangelos',
#  'muisne',
#  'tahoua',
#  'barentsburg',
#  'karratha',
#  'harper',
#  'praia da vitoria',
#  'trofors',
#  'kushima',
#  'port-gentil',
#  'longyearbyen',
#  'kahului',
#  'hambantota',
#  'mankono',
#  'maku',
#  'nizhneyansk',
#  'tsihombe',
#  'san quintin',
#  'norden',
#  'sug-aksy',
#  'bethel',
#  'saint-pierre',
#  'meschede',
#  'porto novo',
#  'portland',
#  'kallidaikurichchi',
#  'luderitz',
#  'guiratinga',
#  'rungata',
#  'urusha',
#  'khatanga',
#  'darnah',
#  'vardo',
#  'samusu',
#  'am timan',
#  'souillac',
#  'ordubad',
#  'hinckley',
#  'fort nelson',
#  'srednekolymsk',
#  'cayenne',
#  'aksarka',
#  'jerez',
#  'batemans bay',
#  'lethem',
#  'lucapa',
#  'jumla',
#  'armilla',
#  'gao',
#  'westport',
#  'ilheus',
#  'lumut',
#  'nileshwar',
#  'buariki',
#  'katherine',
#  'kapit',
#  'aklavik',
#  'hobyo',
#  'maneadero',
#  'back mountain',
#  'humaita',
#  'lolua',
#  'walvis bay',
#  'najran',
#  'port-cartier',
#  'severomuysk',
#  'narsaq',
#  'flinders',
#  'kuche',
#  'hurricane',
#  'mackenzie',
#  'latung',
#  'goderich',
#  'nakamura',
#  'novyy urgal',
#  'hofn',
#  'ovalle',
#  'cidreira',
#  'toliary',
#  'sargatskoye',
#  'rosarito',
#  'salvador',
#  'yelizovo',
#  'shaoyang',
#  'santa rosa',
#  'berdigestyakh',
#  'opuwo',
#  'launceston',
#  'ambanja',
#  'otaru',
#  'tuatapere',
#  'lubao',
#  'naryan-mar',
#  'bilibino',
#  'coffs harbour',
#  'caxito',
#  'mosetse',
#  'husavik',
#  'leshukonskoye',
#  'lompoc',
#  'east hemet',
#  'khanpur',
#  'ewo',
#  'arlit',
#  'mecca',
#  'yeppoon',
#  'chifeng',
#  'bayji',
#  'villa del rosario',
#  'praia',
#  'mookane',
#  'maniitsoq',
#  'kayerkan',
#  'vaitupu',
#  'san rafael',
#  'batticaloa',
#  'saquena',
#  'zyryanka',
#  'tommot',
#  'tanout',
#  'damietta',
#  'sao miguel',
#  'beibei',
#  'vila',
#  'hami',
#  'yarada',
#  'tarakan',
#  'gornopravdinsk',
#  'aasiaat',
#  'srivardhan',
#  'xinxiang',
#  'cherskiy',
#  'daru',
#  'cabedelo',
#  'meadow lake',
#  'salalah',
#  'ibra',
#  'sorland',
#  'san lorenzo',
#  'fez',
#  'magadan',
#  'manggar',
#  'isangel',
#  'alashtar',
#  'gympie',
#  'cortez',
#  'meulaboh',
#  'necochea',
#  'banes',
#  'port lincoln',
#  'maldonado',
#  'soubre',
#  'ambon',
#  'turayf',
#  'carutapera',
#  'comodoro rivadavia',
#  'svetlyy',
#  'cheyenne',
#  'tecpan',
#  'safaqis',
#  'port augusta',
#  'amga',
#  'vao',
#  'esso',
#  'ayan',
#  'beihai',
#  'pihani',
#  'dolbeau',
#  'sande',
#  'monte cristi',
#  'zhezkazgan',
#  'grand gaube',
#  'grand-santi',
#  'sobolevo',
#  'namibe',
#  'miles city',
#  'agbor',
#  'ransang',
#  'jardin',
#  'komsomolskiy',
#  'pilar',
#  'adre',
#  'atar',
#  'alihe',
#  'iqaluit',
#  'sinnamary',
#  'alta floresta',
#  'polis',
#  'seoul',
#  'raga',
#  'ruatoria',
#  'francofonte',
#  'caledon',
#  'bilma',
#  'whitianga',
#  'tabou',
#  'kavieng',
#  'ordu',
#  'rapid city',
#  'dafeng',
#  'svencionys',
#  'bambanglipuro',
#  'dudinka',
#  'vila franca do campo',
#  'kuldiga',
#  'dunedin',
#  'lahaina',
#  'de aar',
#  'dahra',
#  'mount gambier',
#  'sola',
#  'emba',
#  'erzin',
#  'tiarei',
#  'muana',
#  'rudbar',
#  'pauini',
#  'dien bien',
#  'timmins',
#  'nizwa',
#  'ancud',
#  'parchim',
#  'auki',
#  'grindavik',
#  'nouadhibou',
#  'coihaique',
#  'elko',
#  'bacolod',
#  'amazar',
#  'broken hill',
#  'leh',
#  'chiredzi',
#  'castanos',
#  'mackay',
#  'zhigansk',
#  'dicabisagan',
#  'dzhebariki-khaya',
#  'lagoa',
#  'sur',
#  'hagere hiywet',
#  'papara',
#  'ust-bolsheretsk',
#  'cap malheureux',
#  'honolulu',
#  'jinchang',
#  'ngukurr',
#  'marcona',
#  'thinadhoo',
#  'shetpe',
#  'vung tau',
#  'fevralsk',
#  'baoro',
#  'tam ky',
#  'sao joao da barra',
#  'cockburn town',
#  'college',
#  'broome',
#  'bafoulabe',
#  'japura',
#  'penzance',
#  'cariati',
#  'tanete',
#  'orlik',
#  'dharmadam',
#  'nishihara',
#  'taozhuang',
#  'belogorsk',
#  'bahawalpur',
#  'ust-tsilma',
#  'ola',
#  'ust-kuyga',
#  'ahipara',
#  'beruwala',
#  'trud',
#  'namatanai',
#  'lasa',
#  'takahata',
#  'karasjok',
#  'coquimbo',
#  'traian',
#  'bay roberts',
#  'tiznit',
#  'la ciotat',
#  'kasangulu',
#  'beringovskiy',
#  'minot',
#  'katima mulilo',
#  'praya',
#  'luau',
#  'puerto baquerizo moreno',
#  'kabompo',
#  'kaeo',
#  'saint george',
#  'aguimes',
#  'nelson bay',
#  'salaga',
#  'acurenam',
#  'chokurdakh',
#  'vitim',
#  'mahadday weyne',
#  'show low',
#  'sarankhola',
#  'naze',
#  'tungor',
#  'warqla',
#  'nizhniy kuranakh',
#  'lavrentiya',
#  'aginskoye',
#  'ulaanbaatar',
#  'eskil',
#  'verkhnevilyuysk',
#  'superior',
#  'hervey bay',
#  'xiongzhou',
#  'tubruq',
#  'guasdualito',
#  'winslow',
#  'foam lake',
#  'kerrville',
#  'tucuman',
#  'clyde river',
#  'khagrachari',
#  'meyungs',
#  'pangody',
#  'urbano santos',
#  'nome',
#  'viru',
#  'yingzhong',
#  'shimoda',
#  'ati',
#  'valdivia',
#  'phalodi',
#  'san jeronimo',
#  'kolobrzeg',
#  'port blair',
#  'rio gallegos',
#  'taltal',
#  'pareora',
#  'camacha',
#  'breznik',
#  'chagda',
#  'mosoaia',
#  'sorvag',
#  'kurtamysh',
#  'malakal',
#  'akdagmadeni',
#  'aykhal',
#  'abbeville',
#  'kungurtug',
#  'planaltina',
#  'abay',
#  'seymchan',
#  'hays',
#  'dalbandin',
#  'muros',
#  'vanavara',
#  'xinmin',
#  'kyshtovka',
#  'guajara-mirim',
#  'marystown',
#  'faanui',
#  'mogocha',
#  'slave lake',
#  'bonfim',
#  'kyaikto',
#  'jardim',
#  'vilyuysk',
#  'iroquois falls',
#  'santana',
#  'perth',
#  'los llanos de aridane',
#  'andenes',
#  'okhotsk',
#  'matveyevka',
#  'rancho palos verdes',
#  'laguna',
#  'tadine',
#  'huejuquilla el alto',
#  'franca',
#  'honavar',
#  'pangoa',
#  'plon',
#  'garden city',
#  'moron',
#  'yerbogachen',
#  'sijunjung',
#  'asayita',
#  'mikuni',
#  'nizhneudinsk',
#  'southbridge',
#  'roald',
#  'tabory',
#  'medicine hat',
#  'adrar',
#  'pakxan',
#  'hualmay',
#  'uyuni',
#  'halalo',
#  'malwan',
#  'bara',
#  'ulaangom',
#  'tsumeb',
#  'camopi',
#  'shenjiamen',
#  'mori',
#  'gebze',
#  'umm lajj',
#  'tabiauea',
#  'phan thiet',
#  'fare',
#  'somerset',
#  'evensk',
#  'nabire',
#  'zalantun',
#  'kusk',
#  'atka',
#  'pahrump',
#  'gallup',
#  'riverton',
#  'ilukste',
#  'sume',
#  'paamiut',
#  'tsimlyansk',
#  'williams lake',
#  'tabas',
#  'sitio novo do tocantins',
#  'chimbote',
#  'mananjary',
#  'naukot',
#  'olutanga',
#  'acapulco',
#  'onega',
#  'bad tolz',
#  'korop',
#  'shingu',
#  'tessalit',
#  'urumqi',
#  'nuuk',
#  'antalaha',
#  'tabuk',
#  'biak',
#  'zheshart',
#  'belaya gora',
#  'xian',
#  'mahbubnagar',
#  'nantucket',
#  'ahmadnagar',
#  'angra',
#  'liverpool',
#  'yankton',
#  'noumea',
#  'katobu',
#  'antofagasta',
#  'kumluca',
#  'dalvik',
#  'vaitape',
#  'saint-augustin',
#  'sisimiut',
#  'hokitika',
#  'boksitogorsk',
#  'otjimbingwe',
#  'oksfjord',
#  'clarksville',
#  'sapao',
#  'jinji',
#  'khani',
#  'te anau',
#  'nador',
#  'wairoa',
#  'henderson',
#  'tacuarembo',
#  'yarkovo',
#  'henties bay',
#  'chipinge',
#  'policoro',
#  'kiama',
#  'angoche',
#  'hsinchu',
#  'itarema',
#  'cordoba',
#  'pedasi',
#  'chaa-khol',
#  'basco',
#  'brekstad',
#  'shuyskoye',
#  'poum',
#  'kut chap',
#  'port moresby',
#  'jalu',
#  'nhulunbuy',
#  'changchun',
#  'fomboni',
#  'ankazobe',
#  'kurchum',
#  'lundazi',
#  'mukdahan',
#  'kavarna',
#  'macae',
#  'borama',
#  'monte patria',
#  'joshimath',
#  'wajima',
#  'matay',
#  'san cristobal',
#  'burla',
#  'lekoni',
#  'uray',
#  'labutta',
#  'chulman',
#  'sri aman',
#  'la ronge',
#  'maihar',
#  'ekibastuz',
#  'bassano',
#  'lotofaga',
#  'lydenburg',
#  'twin falls',
#  'saryagash',
#  'nyimba',
#  'sayyan',
#  'nicoya',
#  'moerai',
#  'ngunguru',
#  'dubrovnik',
#  'saint simons',
#  'charyshskoye',
#  'lashio',
#  'port macquarie',
#  'mrirt',
#  'todos santos',
#  'pallasovka',
#  'barra do garcas',
#  'usvyaty',
#  'port shepstone',
#  'hirara',
#  'bubaque',
#  'pajapan',
#  'havre-saint-pierre',
#  'wahran',
#  'palmer',
#  'pierre',
#  'qasigiannguit',
#  'san rafael del sur',
#  'ingham',
#  'dormidontovka',
#  'filadelfia']

# %%
len(cities)
# Out:
# 762

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# %%
#delete later
city_url = url + "&q=" + "victoria"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a6da1a845cc9d4e72a72f7147a3a339&q=victoria

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]['description']
                
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | manaus
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | cervo
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | kloulklubed
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | labuhan
# Processing Record 17 of Set 1 | airai
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | chicama
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | kapoeta
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | kirakira
# Processing Record 26 of Set 1 | sembe
# Processing Record 27 of Set 1 | tazovskiy
# Processing Record 28 of Set 1 | qandahar
# City not found. Skipping...
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | yulara
# Processing Record 31 of Set 1 | port hawkesbury
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | kitui
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | makakilo city
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | traverse city
# Processing Record 40 of Set 1 | mitu
# Processing Record 41 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | oistins
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | fairbanks
# Processing Record 48 of Set 1 | sitka
# Processing Record 49 of Set 1 | zvishavane
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | mareeba
# Processing Record 2 of Set 2 | pochutla
# Processing Record 3 of Set 2 | galesong
# Processing Record 4 of Set 2 | vostok
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | pangnirtung
# Processing Record 7 of Set 2 | sam chuk
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | batyrevo
# Processing Record 10 of Set 2 | vestmannaeyjar
# Processing Record 11 of Set 2 | barcelos
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | klaksvik
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | saskylakh
# Processing Record 18 of Set 2 | lovington
# Processing Record 19 of Set 2 | mayo
# Processing Record 20 of Set 2 | margate
# Processing Record 21 of Set 2 | porto velho
# Processing Record 22 of Set 2 | villazon
# Processing Record 23 of Set 2 | alofi
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | sierra vista
# Processing Record 26 of Set 2 | sehithwa
# Processing Record 27 of Set 2 | san patricio
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | salinopolis
# Processing Record 33 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 2 | jiuquan
# Processing Record 35 of Set 2 | sirari
# Processing Record 36 of Set 2 | rawson
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | richards bay
# Processing Record 40 of Set 2 | winthrop
# Processing Record 41 of Set 2 | half moon bay
# Processing Record 42 of Set 2 | astana
# Processing Record 43 of Set 2 | oriximina
# Processing Record 44 of Set 2 | tual
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | fallon
# Processing Record 47 of Set 2 | dasoguz
# Processing Record 48 of Set 2 | saldanha
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | hasaki
# Processing Record 1 of Set 3 | rock springs
# Processing Record 2 of Set 3 | ixtapa
# Processing Record 3 of Set 3 | faya
# Processing Record 4 of Set 3 | hay river
# Processing Record 5 of Set 3 | torbay
# Processing Record 6 of Set 3 | chake chake
# Processing Record 7 of Set 3 | kodinar
# Processing Record 8 of Set 3 | mehamn
# Processing Record 9 of Set 3 | teguldet
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | padang
# Processing Record 13 of Set 3 | eureka
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | kabanjahe
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | bamnet narong
# Processing Record 18 of Set 3 | waipawa
# Processing Record 19 of Set 3 | tura
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | maceio
# Processing Record 23 of Set 3 | yaan
# Processing Record 24 of Set 3 | christchurch
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | mazyr
# Processing Record 27 of Set 3 | pelym
# Processing Record 28 of Set 3 | hovd
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | grimari
# City not found. Skipping...
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | qandala
# Processing Record 33 of Set 3 | ranfurly
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | priladozhskiy
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | yumen
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | beloha
# Processing Record 42 of Set 3 | marsa matruh
# Processing Record 43 of Set 3 | bairiki
# Processing Record 44 of Set 3 | ust-maya
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | kerema
# Processing Record 48 of Set 3 | east london
# Processing Record 49 of Set 3 | puerto colombia
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | olafsvik
# Processing Record 2 of Set 4 | tias
# Processing Record 3 of Set 4 | ilulissat
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | sao filipe
# Processing Record 8 of Set 4 | hamilton
# Processing Record 9 of Set 4 | udachnyy
# Processing Record 10 of Set 4 | novyy urengoy
# Processing Record 11 of Set 4 | almaznyy
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | novikovo
# Processing Record 14 of Set 4 | hue
# Processing Record 15 of Set 4 | kemin
# Processing Record 16 of Set 4 | tilichiki
# Processing Record 17 of Set 4 | flin flon
# Processing Record 18 of Set 4 | oppdal
# Processing Record 19 of Set 4 | luangwa
# Processing Record 20 of Set 4 | cardston
# Processing Record 21 of Set 4 | barrow
# Processing Record 22 of Set 4 | hilo
# Processing Record 23 of Set 4 | gat
# Processing Record 24 of Set 4 | progreso
# Processing Record 25 of Set 4 | arcata
# Processing Record 26 of Set 4 | aksay
# Processing Record 27 of Set 4 | santa maria
# Processing Record 28 of Set 4 | codrington
# Processing Record 29 of Set 4 | kamina
# Processing Record 30 of Set 4 | imeni poliny osipenko
# Processing Record 31 of Set 4 | puerto ayora
# Processing Record 32 of Set 4 | boundiali
# Processing Record 33 of Set 4 | bauchi
# Processing Record 34 of Set 4 | khandyga
# Processing Record 35 of Set 4 | patitirion
# Processing Record 36 of Set 4 | saint-leu
# Processing Record 37 of Set 4 | leiyang
# Processing Record 38 of Set 4 | port hardy
# Processing Record 39 of Set 4 | jamestown
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | khandbari
# Processing Record 43 of Set 4 | cabo san lucas
# Processing Record 44 of Set 4 | marzuq
# Processing Record 45 of Set 4 | rafiganj
# Processing Record 46 of Set 4 | champerico
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | zhangye
# Processing Record 49 of Set 4 | calvia
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | guerrero negro
# Processing Record 4 of Set 5 | blackwater
# Processing Record 5 of Set 5 | cegrane
# Processing Record 6 of Set 5 | bangassou
# Processing Record 7 of Set 5 | saint anthony
# Processing Record 8 of Set 5 | waingapu
# Processing Record 9 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 5 | uberaba
# Processing Record 11 of Set 5 | asau
# Processing Record 12 of Set 5 | tirodi
# Processing Record 13 of Set 5 | jieshi
# Processing Record 14 of Set 5 | pawayan
# Processing Record 15 of Set 5 | hithadhoo
# Processing Record 16 of Set 5 | carballo
# Processing Record 17 of Set 5 | arkhangelos
# City not found. Skipping...
# Processing Record 18 of Set 5 | muisne
# Processing Record 19 of Set 5 | tahoua
# Processing Record 20 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 5 | karratha
# Processing Record 22 of Set 5 | harper
# Processing Record 23 of Set 5 | praia da vitoria
# Processing Record 24 of Set 5 | trofors
# Processing Record 25 of Set 5 | kushima
# Processing Record 26 of Set 5 | port-gentil
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | kahului
# Processing Record 29 of Set 5 | hambantota
# Processing Record 30 of Set 5 | mankono
# Processing Record 31 of Set 5 | maku
# Processing Record 32 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 5 | san quintin
# Processing Record 35 of Set 5 | norden
# Processing Record 36 of Set 5 | sug-aksy
# City not found. Skipping...
# Processing Record 37 of Set 5 | bethel
# Processing Record 38 of Set 5 | saint-pierre
# Processing Record 39 of Set 5 | meschede
# Processing Record 40 of Set 5 | porto novo
# Processing Record 41 of Set 5 | portland
# Processing Record 42 of Set 5 | kallidaikurichchi
# Processing Record 43 of Set 5 | luderitz
# Processing Record 44 of Set 5 | guiratinga
# Processing Record 45 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 5 | urusha
# Processing Record 47 of Set 5 | khatanga
# Processing Record 48 of Set 5 | darnah
# Processing Record 49 of Set 5 | vardo
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | am timan
# Processing Record 2 of Set 6 | souillac
# Processing Record 3 of Set 6 | ordubad
# Processing Record 4 of Set 6 | hinckley
# Processing Record 5 of Set 6 | fort nelson
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | cayenne
# Processing Record 8 of Set 6 | aksarka
# Processing Record 9 of Set 6 | jerez
# Processing Record 10 of Set 6 | batemans bay
# Processing Record 11 of Set 6 | lethem
# Processing Record 12 of Set 6 | lucapa
# Processing Record 13 of Set 6 | jumla
# Processing Record 14 of Set 6 | armilla
# Processing Record 15 of Set 6 | gao
# Processing Record 16 of Set 6 | westport
# Processing Record 17 of Set 6 | ilheus
# Processing Record 18 of Set 6 | lumut
# Processing Record 19 of Set 6 | nileshwar
# Processing Record 20 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 6 | katherine
# Processing Record 22 of Set 6 | kapit
# Processing Record 23 of Set 6 | aklavik
# Processing Record 24 of Set 6 | hobyo
# Processing Record 25 of Set 6 | maneadero
# Processing Record 26 of Set 6 | back mountain
# Processing Record 27 of Set 6 | humaita
# Processing Record 28 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 6 | walvis bay
# Processing Record 30 of Set 6 | najran
# Processing Record 31 of Set 6 | port-cartier
# Processing Record 32 of Set 6 | severomuysk
# Processing Record 33 of Set 6 | narsaq
# Processing Record 34 of Set 6 | flinders
# Processing Record 35 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 6 | hurricane
# Processing Record 37 of Set 6 | mackenzie
# Processing Record 38 of Set 6 | latung
# Processing Record 39 of Set 6 | goderich
# Processing Record 40 of Set 6 | nakamura
# Processing Record 41 of Set 6 | novyy urgal
# Processing Record 42 of Set 6 | hofn
# Processing Record 43 of Set 6 | ovalle
# Processing Record 44 of Set 6 | cidreira
# Processing Record 45 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 6 | sargatskoye
# Processing Record 47 of Set 6 | rosarito
# Processing Record 48 of Set 6 | salvador
# Processing Record 49 of Set 6 | yelizovo
# Processing Record 50 of Set 6 | shaoyang
# Processing Record 1 of Set 7 | santa rosa
# Processing Record 2 of Set 7 | berdigestyakh
# Processing Record 3 of Set 7 | opuwo
# Processing Record 4 of Set 7 | launceston
# Processing Record 5 of Set 7 | ambanja
# Processing Record 6 of Set 7 | otaru
# Processing Record 7 of Set 7 | tuatapere
# Processing Record 8 of Set 7 | lubao
# Processing Record 9 of Set 7 | naryan-mar
# Processing Record 10 of Set 7 | bilibino
# Processing Record 11 of Set 7 | coffs harbour
# Processing Record 12 of Set 7 | caxito
# Processing Record 13 of Set 7 | mosetse
# Processing Record 14 of Set 7 | husavik
# Processing Record 15 of Set 7 | leshukonskoye
# Processing Record 16 of Set 7 | lompoc
# Processing Record 17 of Set 7 | east hemet
# Processing Record 18 of Set 7 | khanpur
# Processing Record 19 of Set 7 | ewo
# Processing Record 20 of Set 7 | arlit
# Processing Record 21 of Set 7 | mecca
# Processing Record 22 of Set 7 | yeppoon
# Processing Record 23 of Set 7 | chifeng
# Processing Record 24 of Set 7 | bayji
# Processing Record 25 of Set 7 | villa del rosario
# Processing Record 26 of Set 7 | praia
# Processing Record 27 of Set 7 | mookane
# Processing Record 28 of Set 7 | maniitsoq
# Processing Record 29 of Set 7 | kayerkan
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | san rafael
# Processing Record 32 of Set 7 | batticaloa
# Processing Record 33 of Set 7 | saquena
# Processing Record 34 of Set 7 | zyryanka
# Processing Record 35 of Set 7 | tommot
# Processing Record 36 of Set 7 | tanout
# Processing Record 37 of Set 7 | damietta
# Processing Record 38 of Set 7 | sao miguel
# Processing Record 39 of Set 7 | beibei
# Processing Record 40 of Set 7 | vila
# Processing Record 41 of Set 7 | hami
# Processing Record 42 of Set 7 | yarada
# Processing Record 43 of Set 7 | tarakan
# Processing Record 44 of Set 7 | gornopravdinsk
# Processing Record 45 of Set 7 | aasiaat
# Processing Record 46 of Set 7 | srivardhan
# Processing Record 47 of Set 7 | xinxiang
# Processing Record 48 of Set 7 | cherskiy
# Processing Record 49 of Set 7 | daru
# Processing Record 50 of Set 7 | cabedelo
# Processing Record 1 of Set 8 | meadow lake
# Processing Record 2 of Set 8 | salalah
# Processing Record 3 of Set 8 | ibra
# Processing Record 4 of Set 8 | sorland
# Processing Record 5 of Set 8 | san lorenzo
# Processing Record 6 of Set 8 | fez
# Processing Record 7 of Set 8 | magadan
# Processing Record 8 of Set 8 | manggar
# Processing Record 9 of Set 8 | isangel
# Processing Record 10 of Set 8 | alashtar
# City not found. Skipping...
# Processing Record 11 of Set 8 | gympie
# Processing Record 12 of Set 8 | cortez
# Processing Record 13 of Set 8 | meulaboh
# Processing Record 14 of Set 8 | necochea
# Processing Record 15 of Set 8 | banes
# Processing Record 16 of Set 8 | port lincoln
# Processing Record 17 of Set 8 | maldonado
# Processing Record 18 of Set 8 | soubre
# Processing Record 19 of Set 8 | ambon
# Processing Record 20 of Set 8 | turayf
# Processing Record 21 of Set 8 | carutapera
# Processing Record 22 of Set 8 | comodoro rivadavia
# Processing Record 23 of Set 8 | svetlyy
# Processing Record 24 of Set 8 | cheyenne
# Processing Record 25 of Set 8 | tecpan
# Processing Record 26 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 27 of Set 8 | port augusta
# Processing Record 28 of Set 8 | amga
# Processing Record 29 of Set 8 | vao
# Processing Record 30 of Set 8 | esso
# Processing Record 31 of Set 8 | ayan
# Processing Record 32 of Set 8 | beihai
# Processing Record 33 of Set 8 | pihani
# Processing Record 34 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 8 | sande
# Processing Record 36 of Set 8 | monte cristi
# City not found. Skipping...
# Processing Record 37 of Set 8 | zhezkazgan
# Processing Record 38 of Set 8 | grand gaube
# Processing Record 39 of Set 8 | grand-santi
# Processing Record 40 of Set 8 | sobolevo
# Processing Record 41 of Set 8 | namibe
# Processing Record 42 of Set 8 | miles city
# Processing Record 43 of Set 8 | agbor
# Processing Record 44 of Set 8 | ransang
# Processing Record 45 of Set 8 | jardin
# Processing Record 46 of Set 8 | komsomolskiy
# Processing Record 47 of Set 8 | pilar
# Processing Record 48 of Set 8 | adre
# Processing Record 49 of Set 8 | atar
# Processing Record 50 of Set 8 | alihe
# Processing Record 1 of Set 9 | iqaluit
# Processing Record 2 of Set 9 | sinnamary
# Processing Record 3 of Set 9 | alta floresta
# Processing Record 4 of Set 9 | polis
# Processing Record 5 of Set 9 | seoul
# Processing Record 6 of Set 9 | raga
# Processing Record 7 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 9 | francofonte
# Processing Record 9 of Set 9 | caledon
# Processing Record 10 of Set 9 | bilma
# Processing Record 11 of Set 9 | whitianga
# Processing Record 12 of Set 9 | tabou
# Processing Record 13 of Set 9 | kavieng
# Processing Record 14 of Set 9 | ordu
# Processing Record 15 of Set 9 | rapid city
# Processing Record 16 of Set 9 | dafeng
# Processing Record 17 of Set 9 | svencionys
# Processing Record 18 of Set 9 | bambanglipuro
# Processing Record 19 of Set 9 | dudinka
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | kuldiga
# Processing Record 22 of Set 9 | dunedin
# Processing Record 23 of Set 9 | lahaina
# Processing Record 24 of Set 9 | de aar
# Processing Record 25 of Set 9 | dahra
# Processing Record 26 of Set 9 | mount gambier
# Processing Record 27 of Set 9 | sola
# Processing Record 28 of Set 9 | emba
# Processing Record 29 of Set 9 | erzin
# Processing Record 30 of Set 9 | tiarei
# Processing Record 31 of Set 9 | muana
# Processing Record 32 of Set 9 | rudbar
# Processing Record 33 of Set 9 | pauini
# Processing Record 34 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 9 | timmins
# Processing Record 36 of Set 9 | nizwa
# Processing Record 37 of Set 9 | ancud
# Processing Record 38 of Set 9 | parchim
# Processing Record 39 of Set 9 | auki
# Processing Record 40 of Set 9 | grindavik
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | coihaique
# Processing Record 43 of Set 9 | elko
# Processing Record 44 of Set 9 | bacolod
# Processing Record 45 of Set 9 | amazar
# Processing Record 46 of Set 9 | broken hill
# Processing Record 47 of Set 9 | leh
# Processing Record 48 of Set 9 | chiredzi
# Processing Record 49 of Set 9 | castanos
# Processing Record 50 of Set 9 | mackay
# Processing Record 1 of Set 10 | zhigansk
# Processing Record 2 of Set 10 | dicabisagan
# Processing Record 3 of Set 10 | dzhebariki-khaya
# Processing Record 4 of Set 10 | lagoa
# Processing Record 5 of Set 10 | sur
# Processing Record 6 of Set 10 | hagere hiywet
# Processing Record 7 of Set 10 | papara
# Processing Record 8 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 9 of Set 10 | cap malheureux
# Processing Record 10 of Set 10 | honolulu
# Processing Record 11 of Set 10 | jinchang
# Processing Record 12 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 10 | thinadhoo
# Processing Record 15 of Set 10 | shetpe
# Processing Record 16 of Set 10 | vung tau
# Processing Record 17 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 10 | baoro
# Processing Record 19 of Set 10 | tam ky
# Processing Record 20 of Set 10 | sao joao da barra
# Processing Record 21 of Set 10 | cockburn town
# Processing Record 22 of Set 10 | college
# Processing Record 23 of Set 10 | broome
# Processing Record 24 of Set 10 | bafoulabe
# Processing Record 25 of Set 10 | japura
# Processing Record 26 of Set 10 | penzance
# Processing Record 27 of Set 10 | cariati
# Processing Record 28 of Set 10 | tanete
# Processing Record 29 of Set 10 | orlik
# Processing Record 30 of Set 10 | dharmadam
# Processing Record 31 of Set 10 | nishihara
# Processing Record 32 of Set 10 | taozhuang
# Processing Record 33 of Set 10 | belogorsk
# Processing Record 34 of Set 10 | bahawalpur
# City not found. Skipping...
# Processing Record 35 of Set 10 | ust-tsilma
# City not found. Skipping...
# Processing Record 36 of Set 10 | ola
# Processing Record 37 of Set 10 | ust-kuyga
# Processing Record 38 of Set 10 | ahipara
# Processing Record 39 of Set 10 | beruwala
# Processing Record 40 of Set 10 | trud
# Processing Record 41 of Set 10 | namatanai
# Processing Record 42 of Set 10 | lasa
# Processing Record 43 of Set 10 | takahata
# Processing Record 44 of Set 10 | karasjok
# Processing Record 45 of Set 10 | coquimbo
# Processing Record 46 of Set 10 | traian
# Processing Record 47 of Set 10 | bay roberts
# Processing Record 48 of Set 10 | tiznit
# Processing Record 49 of Set 10 | la ciotat
# Processing Record 50 of Set 10 | kasangulu
# Processing Record 1 of Set 11 | beringovskiy
# Processing Record 2 of Set 11 | minot
# Processing Record 3 of Set 11 | katima mulilo
# Processing Record 4 of Set 11 | praya
# Processing Record 5 of Set 11 | luau
# Processing Record 6 of Set 11 | puerto baquerizo moreno
# Processing Record 7 of Set 11 | kabompo
# Processing Record 8 of Set 11 | kaeo
# Processing Record 9 of Set 11 | saint george
# Processing Record 10 of Set 11 | aguimes
# Processing Record 11 of Set 11 | nelson bay
# Processing Record 12 of Set 11 | salaga
# Processing Record 13 of Set 11 | acurenam
# Processing Record 14 of Set 11 | chokurdakh
# Processing Record 15 of Set 11 | vitim
# Processing Record 16 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 11 | show low
# Processing Record 18 of Set 11 | sarankhola
# Processing Record 19 of Set 11 | naze
# Processing Record 20 of Set 11 | tungor
# Processing Record 21 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 11 | nizhniy kuranakh
# Processing Record 23 of Set 11 | lavrentiya
# Processing Record 24 of Set 11 | aginskoye
# Processing Record 25 of Set 11 | ulaanbaatar
# Processing Record 26 of Set 11 | eskil
# Processing Record 27 of Set 11 | verkhnevilyuysk
# Processing Record 28 of Set 11 | superior
# Processing Record 29 of Set 11 | hervey bay
# Processing Record 30 of Set 11 | xiongzhou
# Processing Record 31 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 11 | guasdualito
# Processing Record 33 of Set 11 | winslow
# Processing Record 34 of Set 11 | foam lake
# Processing Record 35 of Set 11 | kerrville
# Processing Record 36 of Set 11 | tucuman
# Processing Record 37 of Set 11 | clyde river
# Processing Record 38 of Set 11 | khagrachari
# City not found. Skipping...
# Processing Record 39 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 11 | pangody
# Processing Record 41 of Set 11 | urbano santos
# Processing Record 42 of Set 11 | nome
# Processing Record 43 of Set 11 | viru
# Processing Record 44 of Set 11 | yingzhong
# City not found. Skipping...
# Processing Record 45 of Set 11 | shimoda
# Processing Record 46 of Set 11 | ati
# Processing Record 47 of Set 11 | valdivia
# Processing Record 48 of Set 11 | phalodi
# Processing Record 49 of Set 11 | san jeronimo
# Processing Record 50 of Set 11 | kolobrzeg
# Processing Record 1 of Set 12 | port blair
# Processing Record 2 of Set 12 | rio gallegos
# Processing Record 3 of Set 12 | taltal
# Processing Record 4 of Set 12 | pareora
# Processing Record 5 of Set 12 | camacha
# Processing Record 6 of Set 12 | breznik
# Processing Record 7 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 12 | mosoaia
# Processing Record 9 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 12 | kurtamysh
# Processing Record 11 of Set 12 | malakal
# Processing Record 12 of Set 12 | akdagmadeni
# Processing Record 13 of Set 12 | aykhal
# Processing Record 14 of Set 12 | abbeville
# Processing Record 15 of Set 12 | kungurtug
# Processing Record 16 of Set 12 | planaltina
# Processing Record 17 of Set 12 | abay
# Processing Record 18 of Set 12 | seymchan
# Processing Record 19 of Set 12 | hays
# Processing Record 20 of Set 12 | dalbandin
# Processing Record 21 of Set 12 | muros
# Processing Record 22 of Set 12 | vanavara
# Processing Record 23 of Set 12 | xinmin
# Processing Record 24 of Set 12 | kyshtovka
# Processing Record 25 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 26 of Set 12 | marystown
# Processing Record 27 of Set 12 | faanui
# Processing Record 28 of Set 12 | mogocha
# Processing Record 29 of Set 12 | slave lake
# Processing Record 30 of Set 12 | bonfim
# Processing Record 31 of Set 12 | kyaikto
# Processing Record 32 of Set 12 | jardim
# Processing Record 33 of Set 12 | vilyuysk
# Processing Record 34 of Set 12 | iroquois falls
# Processing Record 35 of Set 12 | santana
# Processing Record 36 of Set 12 | perth
# Processing Record 37 of Set 12 | los llanos de aridane
# Processing Record 38 of Set 12 | andenes
# Processing Record 39 of Set 12 | okhotsk
# Processing Record 40 of Set 12 | matveyevka
# Processing Record 41 of Set 12 | rancho palos verdes
# Processing Record 42 of Set 12 | laguna
# Processing Record 43 of Set 12 | tadine
# Processing Record 44 of Set 12 | huejuquilla el alto
# Processing Record 45 of Set 12 | franca
# Processing Record 46 of Set 12 | honavar
# Processing Record 47 of Set 12 | pangoa
# Processing Record 48 of Set 12 | plon
# Processing Record 49 of Set 12 | garden city
# Processing Record 50 of Set 12 | moron
# Processing Record 1 of Set 13 | yerbogachen
# Processing Record 2 of Set 13 | sijunjung
# Processing Record 3 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 13 | mikuni
# Processing Record 5 of Set 13 | nizhneudinsk
# Processing Record 6 of Set 13 | southbridge
# Processing Record 7 of Set 13 | roald
# Processing Record 8 of Set 13 | tabory
# Processing Record 9 of Set 13 | medicine hat
# Processing Record 10 of Set 13 | adrar
# Processing Record 11 of Set 13 | pakxan
# Processing Record 12 of Set 13 | hualmay
# Processing Record 13 of Set 13 | uyuni
# Processing Record 14 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 13 | bara
# Processing Record 17 of Set 13 | ulaangom
# Processing Record 18 of Set 13 | tsumeb
# Processing Record 19 of Set 13 | camopi
# Processing Record 20 of Set 13 | shenjiamen
# Processing Record 21 of Set 13 | mori
# Processing Record 22 of Set 13 | gebze
# Processing Record 23 of Set 13 | umm lajj
# Processing Record 24 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 13 | phan thiet
# Processing Record 26 of Set 13 | fare
# Processing Record 27 of Set 13 | somerset
# Processing Record 28 of Set 13 | evensk
# Processing Record 29 of Set 13 | nabire
# Processing Record 30 of Set 13 | zalantun
# Processing Record 31 of Set 13 | kusk
# City not found. Skipping...
# Processing Record 32 of Set 13 | atka
# City not found. Skipping...
# Processing Record 33 of Set 13 | pahrump
# Processing Record 34 of Set 13 | gallup
# Processing Record 35 of Set 13 | riverton
# Processing Record 36 of Set 13 | ilukste
# Processing Record 37 of Set 13 | sume
# Processing Record 38 of Set 13 | paamiut
# Processing Record 39 of Set 13 | tsimlyansk
# Processing Record 40 of Set 13 | williams lake
# Processing Record 41 of Set 13 | tabas
# Processing Record 42 of Set 13 | sitio novo do tocantins
# Processing Record 43 of Set 13 | chimbote
# Processing Record 44 of Set 13 | mananjary
# Processing Record 45 of Set 13 | naukot
# Processing Record 46 of Set 13 | olutanga
# Processing Record 47 of Set 13 | acapulco
# Processing Record 48 of Set 13 | onega
# Processing Record 49 of Set 13 | bad tolz
# Processing Record 50 of Set 13 | korop
# Processing Record 1 of Set 14 | shingu
# Processing Record 2 of Set 14 | tessalit
# Processing Record 3 of Set 14 | urumqi
# Processing Record 4 of Set 14 | nuuk
# Processing Record 5 of Set 14 | antalaha
# Processing Record 6 of Set 14 | tabuk
# Processing Record 7 of Set 14 | biak
# Processing Record 8 of Set 14 | zheshart
# Processing Record 9 of Set 14 | belaya gora
# Processing Record 10 of Set 14 | xian
# Processing Record 11 of Set 14 | mahbubnagar
# Processing Record 12 of Set 14 | nantucket
# Processing Record 13 of Set 14 | ahmadnagar
# Processing Record 14 of Set 14 | angra
# City not found. Skipping...
# Processing Record 15 of Set 14 | liverpool
# Processing Record 16 of Set 14 | yankton
# Processing Record 17 of Set 14 | noumea
# Processing Record 18 of Set 14 | katobu
# Processing Record 19 of Set 14 | antofagasta
# Processing Record 20 of Set 14 | kumluca
# Processing Record 21 of Set 14 | dalvik
# Processing Record 22 of Set 14 | vaitape
# Processing Record 23 of Set 14 | saint-augustin
# Processing Record 24 of Set 14 | sisimiut
# Processing Record 25 of Set 14 | hokitika
# Processing Record 26 of Set 14 | boksitogorsk
# Processing Record 27 of Set 14 | otjimbingwe
# Processing Record 28 of Set 14 | oksfjord
# Processing Record 29 of Set 14 | clarksville
# Processing Record 30 of Set 14 | sapao
# City not found. Skipping...
# Processing Record 31 of Set 14 | jinji
# Processing Record 32 of Set 14 | khani
# Processing Record 33 of Set 14 | te anau
# Processing Record 34 of Set 14 | nador
# Processing Record 35 of Set 14 | wairoa
# Processing Record 36 of Set 14 | henderson
# Processing Record 37 of Set 14 | tacuarembo
# Processing Record 38 of Set 14 | yarkovo
# Processing Record 39 of Set 14 | henties bay
# Processing Record 40 of Set 14 | chipinge
# Processing Record 41 of Set 14 | policoro
# Processing Record 42 of Set 14 | kiama
# Processing Record 43 of Set 14 | angoche
# Processing Record 44 of Set 14 | hsinchu
# Processing Record 45 of Set 14 | itarema
# Processing Record 46 of Set 14 | cordoba
# Processing Record 47 of Set 14 | pedasi
# Processing Record 48 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 49 of Set 14 | basco
# Processing Record 50 of Set 14 | brekstad
# Processing Record 1 of Set 15 | shuyskoye
# Processing Record 2 of Set 15 | poum
# Processing Record 3 of Set 15 | kut chap
# Processing Record 4 of Set 15 | port moresby
# Processing Record 5 of Set 15 | jalu
# Processing Record 6 of Set 15 | nhulunbuy
# Processing Record 7 of Set 15 | changchun
# Processing Record 8 of Set 15 | fomboni
# Processing Record 9 of Set 15 | ankazobe
# Processing Record 10 of Set 15 | kurchum
# Processing Record 11 of Set 15 | lundazi
# Processing Record 12 of Set 15 | mukdahan
# Processing Record 13 of Set 15 | kavarna
# Processing Record 14 of Set 15 | macae
# Processing Record 15 of Set 15 | borama
# City not found. Skipping...
# Processing Record 16 of Set 15 | monte patria
# Processing Record 17 of Set 15 | joshimath
# Processing Record 18 of Set 15 | wajima
# Processing Record 19 of Set 15 | matay
# Processing Record 20 of Set 15 | san cristobal
# Processing Record 21 of Set 15 | burla
# Processing Record 22 of Set 15 | lekoni
# Processing Record 23 of Set 15 | uray
# Processing Record 24 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 15 | chulman
# Processing Record 26 of Set 15 | sri aman
# Processing Record 27 of Set 15 | la ronge
# Processing Record 28 of Set 15 | maihar
# Processing Record 29 of Set 15 | ekibastuz
# Processing Record 30 of Set 15 | bassano
# Processing Record 31 of Set 15 | lotofaga
# Processing Record 32 of Set 15 | lydenburg
# Processing Record 33 of Set 15 | twin falls
# Processing Record 34 of Set 15 | saryagash
# Processing Record 35 of Set 15 | nyimba
# Processing Record 36 of Set 15 | sayyan
# Processing Record 37 of Set 15 | nicoya
# Processing Record 38 of Set 15 | moerai
# Processing Record 39 of Set 15 | ngunguru
# Processing Record 40 of Set 15 | dubrovnik
# Processing Record 41 of Set 15 | saint simons
# Processing Record 42 of Set 15 | charyshskoye
# Processing Record 43 of Set 15 | lashio
# Processing Record 44 of Set 15 | port macquarie
# Processing Record 45 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 15 | todos santos
# Processing Record 47 of Set 15 | pallasovka
# Processing Record 48 of Set 15 | barra do garcas
# Processing Record 49 of Set 15 | usvyaty
# Processing Record 50 of Set 15 | port shepstone
# Processing Record 1 of Set 16 | hirara
# Processing Record 2 of Set 16 | bubaque
# Processing Record 3 of Set 16 | pajapan
# Processing Record 4 of Set 16 | havre-saint-pierre
# Processing Record 5 of Set 16 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 16 | palmer
# Processing Record 7 of Set 16 | pierre
# Processing Record 8 of Set 16 | qasigiannguit
# Processing Record 9 of Set 16 | san rafael del sur
# Processing Record 10 of Set 16 | ingham
# Processing Record 11 of Set 16 | dormidontovka
# Processing Record 12 of Set 16 | filadelfia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail()
# Out:
#      Country      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1205      GL  68.8193  -51.1922      7.05        89          89        6.02
# 1206      NI  11.8485  -86.4384     85.17        49          49       18.03
# 1207      US  42.6000  -84.3833     37.35        71         100        8.05
# 1208      RU  47.7702  134.9076     48.85        56          99       10.98
# 1209      US  39.9523  -75.1638     50.70        65         100        8.05
#
#                     City Current Description
# 1205       qasigiannguit     overcast clouds
# 1206  san rafael del sur    scattered clouds
# 1207              ingham     overcast clouds
# 1208       dormidontovka     overcast clouds
# 1209          filadelfia     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.tail()
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 1205       qasigiannguit      GL  68.8193  -51.1922      7.05        89
# 1206  san rafael del sur      NI  11.8485  -86.4384     85.17        49
# 1207              ingham      US  42.6000  -84.3833     37.35        71
# 1208       dormidontovka      RU  47.7702  134.9076     48.85        56
# 1209          filadelfia      US  39.9523  -75.1638     50.70        65
#
#       Cloudiness  Wind Speed Current Description
# 1205          89        6.02     overcast clouds
# 1206          49       18.03    scattered clouds
# 1207         100        8.05     overcast clouds
# 1208          99       10.98     overcast clouds
# 1209         100        8.05     overcast clouds

# %%
len(city_data)
# Out:
# 1210

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
